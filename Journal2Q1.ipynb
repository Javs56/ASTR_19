# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,1,0.01)
def ranges():
    for i in x:
        return np.exp(x)

# %%
y = np.exp(x)
plt.plot(x, y)
plt.xlabel('Time [miliseconds]')
plt.ylabel('Awesomeness')
plt.savefig("Journal2Q1.pdf", bbox_inches="tight",facecolor="white")
